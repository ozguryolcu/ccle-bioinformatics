# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

pd.options.display.float_format = "{:,.12f}".format
pd.options.display.max_columns = 20
pd.options.display.max_rows = 20

# %%
placeholder = []
for x in os.listdir("C:\\Users\\ozgur\\Desktop\\CCLE\\CorrelationValues\\Pearson\\IC50 VALUES"):
    placeholder.append(pd.DataFrame(pd.read_csv("C:\\Users\\ozgur\\Desktop\\CCLE\\CorrelationValues\\Pearson\\IC50 VALUES\\{}".format(x), sep="\t")))
pearsonIC50 = pd.concat(placeholder, ignore_index=True)

placeholder2 = []
for y in os.listdir("C:\\Users\\ozgur\\Desktop\\CCLE\\CorrelationValues\\Pearson\\ActArea VALUES"):
    placeholder2.append(pd.DataFrame(pd.read_csv("C:\\Users\\ozgur\\Desktop\\CCLE\\CorrelationValues\\Pearson\\ActArea VALUES\\{}".format(y), sep="\t")))
pearsonActArea = pd.concat(placeholder2, ignore_index=True)

placeholder3 = []
for z in os.listdir("C:\\Users\\ozgur\\Desktop\\CCLE\\CorrelationValues\\Spearman\\IC50 VALUES"):
    placeholder3.append(pd.DataFrame(pd.read_csv("C:\\Users\\ozgur\\Desktop\\CCLE\\CorrelationValues\\Spearman\\IC50 VALUES\\{}".format(z), sep="\t")))
spearmanIC50 = pd.concat(placeholder3, ignore_index=True)

placeholder4 = []
for t in os.listdir("C:\\Users\\ozgur\\Desktop\\CCLE\\CorrelationValues\\Spearman\\ActArea VALUES"):
    placeholder4.append(pd.DataFrame(pd.read_csv("C:\\Users\\ozgur\\Desktop\\CCLE\\CorrelationValues\\Spearman\\ActArea VALUES\\{}".format(t), sep="\t")))
spearmanActArea = pd.concat(placeholder4, ignore_index=True)

# %%
pearsonActArea
# Out:
#                  Gene Compound  ActArea PearsonCorrelation       P-Values
# 0        CTB-25B13.13   17-AAG             -0.936382365155 0.000007370964
# 1              ZNF460   17-AAG             -0.932811694349 0.000009626198
# 2           LINC00205   17-AAG             -0.908106856766 0.000044153324
# 3         BX322557.10   17-AAG             -0.904465877779 0.000053285366
# 4       RP13-395E19.2   17-AAG             -0.902175052505 0.000059750599
# ...               ...      ...                         ...            ...
# 993856          NUP35  ZD-6474             -0.000039400914 0.999903036813
# 993857        C4orf22  ZD-6474             -0.000023746717 0.999941560813
# 993858         GRIN2B  ZD-6474             -0.000018189043 0.999955237903
# 993859     AC136289.1  ZD-6474              0.000008947136 0.999977981657
# 993860          CASC2  ZD-6474              0.000003305563 0.999991865215
#
# [993861 rows x 4 columns]

# %%
pearsonIC50
# Out:
#                  Gene Compound IC50 PearsonCorrelation       P-Values
# 0           RN7SL288P   17-AAG          0.990361153068 0.000000000645
# 1       CTD-2562J15.6   17-AAG          0.981805107235 0.000000015233
# 2           IGLVIV-59   17-AAG          0.981791385076 0.000000015290
# 3             GUCY2GP   17-AAG          0.981788645005 0.000000015302
# 4         RP3-477M7.6   17-AAG          0.981782824958 0.000000015326
# ...               ...      ...                     ...            ...
# 910630  RP11-656D10.6  ZD-6474         -0.000052040838 0.999871930751
# 910631        FTH1P19  ZD-6474         -0.000046389806 0.999885837586
# 910632         TMEM47  ZD-6474         -0.000036006305 0.999911390733
# 910633           LSM3  ZD-6474          0.000020006185 0.999950766030
# 910634        RIPPLY2  ZD-6474          0.000015363744 0.999962190786
#
# [910635 rows x 4 columns]

# %%
spearmanIC50
# Out:
#                  Gene Compound IC50 SpearmanCorrelation       S-Values
# 0       CITF22-92A6.1   17-AAG           0.931700202890 0.000010429359
# 1                TYW3   17-AAG          -0.931700202890 0.000010429359
# 2              PODNL1   17-AAG           0.924694938207 0.000016790699
# 3         RP11-68I3.7   17-AAG          -0.890529886226 0.000102753922
# 4              RAD23A   17-AAG           0.889668614790 0.000106700248
# ...               ...      ...                      ...            ...
# 910630             TH  ZD-6474           0.000000000000 1.000000000000
# 910631        GCNT1P1  ZD-6474           0.000000000000 1.000000000000
# 910632  RP11-672L10.6  ZD-6474           0.000000000000 1.000000000000
# 910633          WDR75  ZD-6474           0.000000000000 1.000000000000
# 910634       RIMKLBP1  ZD-6474           0.000000000000 1.000000000000
#
# [910635 rows x 4 columns]

# %%
spearmanActArea
# Out:
#                  Gene Compound  ActArea SpearmanCorrelation       S-Values
# 0              PODNL1   17-AAG              -0.930069930070 0.000011702228
# 1              FBXO24   17-AAG              -0.895104895105 0.000083665864
# 2           RNASEH1P2   17-AAG              -0.888111888112 0.000114133598
# 3              CICP16   17-AAG              -0.881118881119 0.000152674065
# 4          AC138744.2   17-AAG               0.880303519005 0.000157757376
# ...               ...      ...                          ...            ...
# 993856    RP4-550H1.5  ZD-6474               0.000000000000 1.000000000000
# 993857  RP11-543D10.2  ZD-6474               0.000000000000 1.000000000000
# 993858            HN1  ZD-6474               0.000000000000 1.000000000000
# 993859        THUMPD2  ZD-6474               0.000000000000 1.000000000000
# 993860    RP11-73B8.2  ZD-6474               0.000000000000 1.000000000000
#
# [993861 rows x 4 columns]

# %%
os.mkdir("C:\\Users\\ozgur\\Desktop\\CCLE\\CorrelationValues\\Filtered")
os.mkdir("C:\\Users\\ozgur\\Desktop\\CCLE\\CorrelationValues\\Filtered\\IC50-ActArea-Pearson")
subset = pearsonIC50.loc[pearsonIC50["P-Values"] < 0.05]
subset2 = pearsonActArea.loc[pearsonActArea["P-Values"] < 0.05]

for x in subset["Compound"].unique():
    placeholder5 = subset.loc[subset["Compound"] == x]
    placeholder6 = subset2.loc[subset2["Compound"] == x]

    pearsonFiltered = pd.merge(placeholder5, placeholder6, on=["Gene", "Compound"], how="inner").reset_index()
    pearsonFiltered.drop(["index"], axis=1).to_csv("C:\\Users\\ozgur\\Desktop\\CCLE\\CorrelationValues\\Filtered\\IC50-ActArea-Pearson\\{}".format(x), index= False, sep="\t")

# %%
os.mkdir("C:\\Users\\ozgur\\Desktop\\CCLE\\CorrelationValues\\Filtered\\IC50-ActArea-Spearman")
subset = spearmanIC50.loc[spearmanIC50["S-Values"] < 0.05]
subset2 = spearmanActArea.loc[spearmanActArea["S-Values"] < 0.05]

for x in subset["Compound"].unique():
    placeholder5 = subset.loc[subset["Compound"] == x]
    placeholder6 = subset2.loc[subset2["Compound"] == x]

    spearmanFiltered = pd.merge(placeholder5, placeholder6, on=["Gene", "Compound"], how="inner").reset_index()
    spearmanFiltered.drop(["index"], axis=1).to_csv("C:\\Users\\ozgur\\Desktop\\CCLE\\CorrelationValues\\Filtered\\IC50-ActArea-Spearman\\{}".format(x), index= False, sep="\t")

# %%
os.mkdir("C:\\Users\\ozgur\\Desktop\\CCLE\\CorrelationValues\\Filtered\\IC50-IC50")
subset = spearmanIC50.loc[spearmanIC50["S-Values"] < 0.05]
subset2 = pearsonIC50.loc[pearsonIC50["P-Values"] < 0.05]

for x in subset["Compound"].unique():
    placeholder5 = subset.loc[subset["Compound"] == x]
    placeholder6 = subset2.loc[subset2["Compound"] == x]

    ic50Filtered = pd.merge(placeholder5, placeholder6, on=["Gene", "Compound"], how="inner").reset_index()
    ic50Filtered.drop(["index"], axis=1).to_csv("C:\\Users\\ozgur\\Desktop\\CCLE\\CorrelationValues\\Filtered\\IC50-IC50\\{}".format(x), index= False, sep="\t")

# %%
os.mkdir("C:\\Users\\ozgur\\Desktop\\CCLE\\CorrelationValues\\Filtered\\ActArea-ActArea")
subset = spearmanActArea.loc[spearmanActArea["S-Values"] < 0.05]
subset2 = pearsonActArea.loc[pearsonActArea["P-Values"] < 0.05]

for x in subset["Compound"].unique():
    placeholder5 = subset.loc[subset["Compound"] == x]
    placeholder6 = subset2.loc[subset2["Compound"] == x]

    actAreaFiltered = pd.merge(placeholder5, placeholder6, on=["Gene", "Compound"], how="inner").reset_index()
    actAreaFiltered.drop(["index"], axis=1).to_csv("C:\\Users\\ozgur\\Desktop\\CCLE\\CorrelationValues\\Filtered\\ActArea-ActArea\\{}".format(x), index= False, sep="\t")
